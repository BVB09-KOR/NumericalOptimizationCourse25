# %% [markdown]
# ## Initialization

# %% [markdown]
# ### 초기화 및 모듈 불러오기

# %%
all = [var for var in globals() if var[0] != '_']
for var in all:
    del globals()[var]
del all

# %%
import numpy as np
import os, sys
import importlib
import matplotlib.pyplot as plt
sys.path.append("../")
import module_opt_AD
importlib.reload(module_opt_AD)
from module_opt_AD import *
from breguet_range_equation_fromprofessor import *
import torch
# Out:
# /home/cykwonlab/NumericalOptimizationCourse25/Assignment_3/../module_opt_AD.py:1344: SyntaxWarning: invalid escape sequence '\:'
#   - list_lmbda (list) : Lagrange multipliers for equality constraints log

# %% [markdown]
# ## Assignment\#3(Constrained Optimization) - Problem 1
# minimize &nbsp; &nbsp; Roesnbrock Function
# subject to &nbsp; &nbsp; c1 = Line
# or
# subject to &nbsp; &nbsp; c2 = disk
#
# 1st Algorithm : QPM(Quadratic Penalty Method)
# 2nd Algorithm : SQP(Sequential Quadratic Programming)

# %% [markdown]
# ### - Rosenbrock Function

# %% [markdown]
# 1. Rosenbrock function on a disk
# min &nbsp; $ f(x_1, x_2) = (1 - x_1)^2 + 100(x_2 - x_1^2)^2 $
# s.t. &nbsp; $ c(x_1, x_2) = 1 - x_1^2 - x_2^2 = 0 $
#
# 2. Rosenbrock function on straight line
# min &nbsp; $ f(x_1, x_2) = (1 - x_1)^2 + 100(x_2 - x_1^2)^2 $
# s.t. &nbsp; $ c(x_1, x_2) = 1 - x_1 - x_2 = 0 $

# %%
### define functions
f_rosenbrock_eqline = lambda x : (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
def f_rosenbrock_eqline_torch(x:torch.Tensor) -> torch.Tensor:
    return (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
c_rosenbrock_eqline = lambda x : 1 - x[0] - x[1]
def c_rosenbrock_eqline_torch(x:torch.Tensor) -> torch.Tensor:
    return 1 - x[0] - x[1]

f_rosenbrock_eqdisk = lambda x : (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
def f_rosenbrock_eqdisk_torch(x:torch.Tensor) -> torch.Tensor:
    return (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
c_rosenbrock_eqdisk = lambda x : 1 - x[0]**2 - x[1]**2
def c_rosenbrock_eqdisk_torch(x:torch.Tensor) -> torch.Tensor:
    return 1 - x[0]**2 - x[1]**2

step_rosenbrock_eq = .01
grid_rosenbrock_eq = np.meshgrid(np.arange(-1.5, 1.5+step_rosenbrock_eq, step_rosenbrock_eq), np.arange(-1.5, 1.5+step_rosenbrock_eq, step_rosenbrock_eq))
fval_grid_rosenbrock_eq = f_rosenbrock_eqline(grid_rosenbrock_eq)

### plot functions
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(6.5, 6*2))

contour_0 = axes[0].contourf(grid_rosenbrock_eq[0], grid_rosenbrock_eq[1], fval_grid_rosenbrock_eq, levels=np.logspace(-3, 3.1))
x_line_eq = np.arange(-0.5, 1.5+.01, .01); y_line_eq = 1 - x_line_eq
axes[0].plot(x_line_eq, y_line_eq, 'k')
axes[0].set_xlabel('x_1'); axes[0].set_ylabel('x_2'); axes[0].set_title('rosenbrock on a line')
fig.colorbar(contour_0, ax=axes[0])

contour_1 = axes[1].contourf(grid_rosenbrock_eq[0], grid_rosenbrock_eq[1], fval_grid_rosenbrock_eq, levels=np.logspace(-3, 3.1))
x_disk_eq = np.arange(-1.0, 1+.0001, .0001); y_disk_eq_pos = (1 - x_disk_eq**2)**.5; y_disk_eq_neg = -(1 - x_disk_eq**2)**.5
axes[1].plot(x_disk_eq, y_disk_eq_pos, 'k') 
axes[1].plot(x_disk_eq, y_disk_eq_neg, 'k')
axes[1].set_xlabel('x_1'); axes[1].set_ylabel('x_2'); axes[1].set_title('rosenbrock on a disk')
fig.colorbar(contour_1, ax=axes[1])

# %%
f1 = f_rosenbrock_eqline # objective function
f1_torch = f_rosenbrock_eqline_torch # objective function torch
ce_1 = [c_rosenbrock_eqline] # equality constraints
ce_1_torch = [c_rosenbrock_eqline_torch] # equality constraints torch
ci_1 = [] # inequality constraints
ci_1_torch = [] # inequality constraints torch
x0_1 = np.array([-.5, -.5])

# %% [markdown]
# ### - Solve Rosenbrock with Line Constraint using SQP, QPM

# %%
result1_qpm = qpm(f=f1, f_torch=f1_torch, ce=ce_1, ce_torch=ce_1_torch, ci=ci_1, ci_torch=ci_1_torch, x0=x0_1, inner_opt=3, tol=1e-6) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
# Out:
# mu_0 = 1
# tau_0 = 0.2
# Since ||grad(x0)|| = 217.0921463342237 > 0.2, x0 : [-0.5 -0.5] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [1.05 1.02]
# f_1 : 1.2555750000000045
# ‖∇f(x_1)‖ : 39.002016614529175
# ‖∆x_1‖ : 2.1709214633422373
# recent alpha : 0.010000000000000002
# recent p : [155. 152.]
#
# BFGS
# x_2 : [1.00840612 1.07762812]
# f_2 : 0.9588041239872191
# ‖∇f(x_2)‖ : 26.883151202913403
# ‖∆x_2‖ : 0.07107075224583657
# recent alpha : 0.0020791192418439333
# recent p : [-20.00553054  27.71756563]
#
# BFGS
# x_3 : [1.017092   1.03501128]
# f_3 : 0.5537814288334768
# ‖∇f(x_3)‖ : 1.4484481498560282
# ‖∆x_3‖ : 0.04349298719509703
# recent alpha : 1
# recent p : [ 0.00868588 -0.04261684]
#
# BFGS
# x_4 : [1.00994053 1.01717362]
# f_4 : 0.5283680558417055
# ‖∇f(x_4)‖ : 2.2298608572911323
# ‖∆x_4‖ : 0.019217846260663314
# recent alpha : 1
# recent p : [-0.00715147 -0.01783766]
#
# BFGS
# x_5 : [0.89968794 0.77402769]
# f_5 : 0.3624006549612313
# ‖∇f(x_5)‖ : 14.688240132850126
# ‖∆x_5‖ : 0.2669748610340009
# recent alpha : 1
# recent p : [-0.11025259 -0.24314593]
#
# BFGS
# x_6 : [0.89878275 0.78727078]
# f_6 : 0.28776738069312474
# ‖∇f(x_6)‖ : 8.57979995866655
# ‖∆x_6‖ : 0.013273993791767148
# recent alpha : 1
# recent p : [-0.00090519  0.01324309]
#
# BFGS
# x_7 : [0.83408342 0.68895838]
# f_7 : 0.16885307772640523
# ‖∇f(x_7)‖ : 2.574360239226401
# ‖∆x_7‖ : 0.11769168667810014
# recent alpha : 1
# recent p : [-0.06469933 -0.09831241]
#
# BFGS
# x_8 : [0.7657824  0.57575184]
# f_8 : 0.12456739844833162
# ‖∇f(x_8)‖ : 3.6171715275420726
# ‖∆x_8‖ : 0.13221478572160322
# recent alpha : 1
# recent p : [-0.06830102 -0.11320654]
#
# BFGS
# x_9 : [0.74195825 0.54643265]
# f_9 : 0.10982619762951773
# ‖∇f(x_9)‖ : 1.1120285826562246
# ‖∆x_9‖ : 0.037778364856714534
# recent alpha : 1
# recent p : [-0.02382415 -0.02931919]
#
# BFGS
# x_10 : [0.72310953 0.52054513]
# f_10 : 0.10690074912731605
# ‖∇f(x_10)‖ : 0.4306825751940695
# ‖∆x_10‖ : 0.03202246497183507
# recent alpha : 1
# recent p : [-0.01884872 -0.02588753]
#
# ‖∇f(x_11)‖ : 0.07108482904171676 / tol_∇f : 0.2 / ‖∆x_11‖ : 0.005624730910464452 / tol_∆x : 0.002
# BFGS
#  Optimization converges -> Iteration : 11 / x* : [0.71928304 0.51642255] / f(x*) : 0.10666997900573266 / ‖∇f(x*)‖ : 0.07108482904171676 ‖∆x*‖ : 0.005624730910464452
#
# 1-th outer loop : Inner loop converges at 11 iteration(s) ...
# |x_1 - x_0| = 1.5873770654382782
# # of violated ce constraints : 1, violation : -0.2357055970612274
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_1 = 5
# tau_1 = 0.1
# Since ||grad(x0)|| = 1.3302329272431874 > 0.1, x0 : [0.71928304 0.51642255] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.63036906 0.41748066]
# f_1 : 0.1828143918646114
# ‖∇f(x_1)‖ : 7.015399438276685
# ‖∆x_1‖ : 0.13302329272431876
# recent alpha : 0.1
# recent p : [-0.88913989 -0.98941897]
#
# BFGS
# x_2 : [0.59724935 0.3520104 ]
# f_2 : 0.17085012752056855
# ‖∇f(x_2)‖ : 1.1946283415642103
# ‖∆x_2‖ : 0.07337077101115558
# recent alpha : 0.003874204890000001
# recent p : [ -8.54877588 -16.89901837]
#
# BFGS
# x_3 : [0.64294738 0.41314835]
# f_3 : 0.13535882988229567
# ‖∇f(x_3)‖ : 0.4408625208612915
# ‖∆x_3‖ : 0.07632928818698335
# recent alpha : 1
# recent p : [0.04569803 0.06113796]
#
# ‖∇f(x_4)‖ : 0.007805789789756009 / tol_∇f : 0.1 / ‖∆x_4‖ : 0.004459384907302413 / tol_∆x : 0.001
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.64627737 0.41611438] / f(x*) : 0.13509490352702988 / ‖∇f(x*)‖ : 0.007805789789756009 ‖∆x*‖ : 0.004459384907302413
#
# 2-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_2 - x_1| = 0.12406272116177988
# # of violated ce constraints : 1, violation : -0.06239174549999471
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_2 = 25
# tau_2 = 0.05
# Since ||grad(x0)|| = 1.7701957468576224 > 0.05, x0 : [0.64627737 0.41611438] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.60687404 0.37695766]
# f_1 : 0.1653179595684424
# ‖∇f(x_1)‖ : 3.5507798792229104
# ‖∆x_1‖ : 0.05555061825173733
# recent alpha : 0.031381059609000006
# recent p : [-1.25564052 -1.24778198]
#
# BFGS
# x_2 : [0.60675364 0.36608977]
# f_2 : 0.16428565373255488
# ‖∇f(x_2)‖ : 1.4567661116963173
# ‖∆x_2‖ : 0.01086855753857601
# recent alpha : 0.004183588659145375
# recent p : [-0.02877834 -2.5977436 ]
#
# BFGS
# x_3 : [0.62474803 0.38835354]
# f_3 : 0.14334249336419538
# ‖∇f(x_3)‖ : 0.09176200549728261
# ‖∆x_3‖ : 0.028626455785122608
# recent alpha : 1
# recent p : [0.01799439 0.02226378]
#
# ‖∇f(x_4)‖ : 0.002544348568623842 / tol_∇f : 0.05 / ‖∆x_4‖ : 0.00025910780491006916 / tol_∆x : 0.0005
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.6247173  0.38861082] / f(x*) : 0.1433334435696966 / ‖∇f(x*)‖ : 0.002544348568623842 ‖∆x*‖ : 0.00025910780491006916
#
# 3-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_3 - x_2| = 0.034946844387045296
# # of violated ce constraints : 1, violation : -0.013328125772012034
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_3 = 125
# tau_3 = 0.025
# Since ||grad(x0)|| = 1.8839620508615094 > 0.025, x0 : [0.6247173  0.38861082] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.61495799 0.37882691]
# f_1 : 0.15071428429052514
# ‖∇f(x_1)‖ : 1.8259017259200792
# ‖∆x_1‖ : 0.013819160664783533
# recent alpha : 0.00733515871960597
# recent p : [-1.33048418 -1.33383839]
#
# BFGS
# x_2 : [0.61586637 0.37747937]
# f_2 : 0.15065444038738982
# ‖∇f(x_2)‖ : 1.6604300054666294
# ‖∆x_2‖ : 0.0016251167678631372
# recent alpha : 0.003989383951490323
# recent p : [ 0.22769824 -0.33778092]
#
# BFGS
# x_3 : [0.62031894 0.38300533]
# f_3 : 0.14516888202160314
# ‖∇f(x_3)‖ : 0.11567533412826143
# ‖∆x_3‖ : 0.0070965898203549874
# recent alpha : 1
# recent p : [0.00445257 0.00552596]
#
# ‖∇f(x_4)‖ : 0.0006742177144530987 / tol_∇f : 0.025 / ‖∆x_4‖ : 0.00043175931961538704 / tol_∆x : 0.00025
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.62000371 0.38271029] / f(x*) : 0.14514461144193447 / ‖∇f(x*)‖ : 0.0006742177144530987 ‖∆x*‖ : 0.00043175931961538704
#
# 4-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_4 - x_3| = 0.007552104641875703
# # of violated ce constraints : 1, violation : -0.002713996279795572
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_4 = 625
# tau_4 = 0.0125
# Since ||grad(x0)|| = 1.918969232637938 > 0.0125, x0 : [0.62000371 0.38271029] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.61796775 0.38067293]
# f_1 : 0.14667276431523912
# ‖∇f(x_1)‖ : 1.7085958924922275
# ‖∆x_1‖ : 0.002880269871189505
# recent alpha : 0.0015009463529699913
# recent p : [-1.35644645 -1.3573857 ]
#
# BFGS
# x_2 : [0.61825031 0.38037464]
# f_2 : 0.14666920741339945
# ‖∇f(x_2)‖ : 1.6937726036505436
# ‖∆x_2‖ : 0.0004108695517017014
# recent alpha : 0.004908242412204496
# recent p : [ 0.05756771 -0.06077287]
#
# BFGS
# x_3 : [0.61933983 0.38183215]
# f_3 : 0.14563752855366896
# ‖∇f(x_3)‖ : 0.5568299916677137
# ‖∆x_3‖ : 0.001819718561156821
# recent alpha : 1
# recent p : [0.00108951 0.00145751]
#
# ‖∇f(x_4)‖ : 0.00014028223745844216 / tol_∇f : 0.0125 / ‖∆x_4‖ : 0.0004438740548289317 / tol_∆x : 0.000125
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.61903818 0.38150652] / f(x*) : 0.1455142211780978 / ‖∇f(x*)‖ : 0.00014028223745844216 ‖∆x*‖ : 0.0004438740548289317
#
# 5-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_5 - x_4| = 0.001543148363104529
# # of violated ce constraints : 1, violation : -0.0005446975145332322
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_5 = 3125
# tau_5 = 0.00625
# Since ||grad(x0)|| = 1.925780445702718 > 0.00625, x0 : [0.61903818 0.38150652] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.61865947 0.38112776]
# f_1 : 0.1457511246787073
# ‖∇f(x_1)‖ : 1.4258471253456393
# ‖∆x_1‖ : 0.0005356142137854444
# recent alpha : 0.00027812838944369354
# recent p : [-1.36163387 -1.36183095]
#
# BFGS
# x_2 : [0.61875398 0.38103414]
# f_2 : 0.1457507671792644
# ‖∇f(x_2)‖ : 1.4148296435716414
# ‖∆x_2‖ : 0.00013303183062382068
# recent alpha : 0.007867570767132147
# recent p : [ 0.01201324 -0.01189926]
#
# BFGS
# x_3 : [0.61886744 0.38124225]
# f_3 : 0.14558871072686078
# ‖∇f(x_3)‖ : 0.016973661416611364
# ‖∆x_3‖ : 0.0002370352188658905
# recent alpha : 0.4699058921630089
# recent p : [0.00024146 0.00044289]
#
# ‖∇f(x_4)‖ : 2.926510072884452e-05 / tol_∇f : 0.00625 / ‖∆x_4‖ : 3.243722459678432e-05 / tol_∆x : 6.25e-05
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.61884417 0.38126485] / f(x*) : 0.14558844597179932 / ‖∇f(x*)‖ : 2.926510072884452e-05 ‖∆x*‖ : 3.243722459678432e-05
#
# 6-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_6 - x_5| = 0.0003099137044903522
# # of violated ce constraints : 1, violation : -0.00010901296025161988
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_6 = 15625
# tau_6 = 0.003125
# Since ||grad(x0)|| = 1.9270867663736904 > 0.003125, x0 : [0.61884417 0.38126485] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.61876461 0.38118529]
# f_1 : 0.14564373131366212
# ‖∇f(x_1)‖ : 1.5895440288656615
# ‖∆x_1‖ : 0.00011250666052537815
# recent alpha : 5.838173064570867e-05
# recent p : [-1.36263628 -1.36267596]
#
# BFGS
# x_2 : [0.61883317 0.38111853]
# f_2 : 0.14564345431016576
# ‖∇f(x_2)‖ : 1.5452068135806238
# ‖∆x_2‖ : 9.569791676720494e-05
# recent alpha : 0.028242953648100005
# recent p : [ 0.00242752 -0.00236396]
#
# BFGS
# x_3 : [0.61883173 0.38119085]
# f_3 : 0.14560364845045826
# ‖∇f(x_3)‖ : 0.026690396191565283
# ‖∆x_3‖ : 7.234294530887311e-05
# recent alpha : 0.12625327766766986
# recent p : [-1.14250467e-05  5.72884639e-04]
#
# ‖∇f(x_4)‖ : 3.431651489221278e-05 / tol_∇f : 0.003125 / ‖∆x_4‖ : 3.6826156722411324e-05 / tol_∆x : 3.125e-05
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.6188053 0.3812165] / f(x*) : 0.14560330310952016 / ‖∇f(x*)‖ : 3.431651489221278e-05 ‖∆x*‖ : 3.6826156722411324e-05
#
# 7-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_7 - x_6| = 6.202894674111573e-05
# # of violated ce constraints : 0, violation : 0.0
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# Outer loop converged at 7 iteration(s) !
# iter = 7 x* = [0.6188053 0.3812165], f(x*) = 0.14559958866094433, |ce(x*)|₁ = 2.1804802629366016e-05, |ci(x*)|₁ = 0.0

# %%
alm(f=f1, f_torch=f1_torch, ce=ce_1, ce_torch=ce_1_torch, ci=ci_1, ci_torch=ci_1_torch, x0=x0_1, inner_opt=3, tol=1e-6) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
# Out:
# mu_0 = 1
# rho_0 = 1
# tau_0 = 0.01
# 1-th outer loop : Inner loop converges at 13 iteration(s) ...
# |x_1 - x_0| = 1.5846724219326334
# Max violation of equality constraints : 0.23178497493194872
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_1 = 5.0
# rho_1 = 1
# tau_1 = 0.005
# 2-th outer loop : Inner loop converges at 6 iteration(s) ...
# |x_2 - x_1| = 0.15162603628397361
# Max violation of equality constraints : 0.019701755257483355
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_2 = 25.0
# rho_2 = 1
# tau_2 = 0.0025
# 3-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_3 - x_2| = 0.013728449938786393
# Max violation of equality constraints : 0.00040729101156461445
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_3 = 25.0
# rho_3 = 1
# tau_3 = 0.00125
# 4-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_4 - x_3| = 0.0002801199911498315
# Max violation of equality constraints : 1.3591665758150295e-05
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_4 = 25.0
# rho_4 = 1
# tau_4 = 0.000625
# 5-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_5 - x_4| = 1.2080154384357887e-05
# Max violation of equality constraints : 3.42409128689658e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_5 = 25.0
# rho_5 = 1
# tau_5 = 0.0003125
# 6-th outer loop : Inner loop converges at 0 iteration(s) ...
# |x_6 - x_5| = 0.0
# Max violation of equality constraints : 3.42409128689658e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_6 = 25.0
# rho_6 = 1
# tau_6 = 0.00015625
# 7-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_7 - x_6| = 4.701140416510245e-06
# Max violation of equality constraints : 3.183719978205879e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_7 = 25.0
# rho_7 = 1
# tau_7 = 7.8125e-05
# 8-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_8 - x_7| = 8.307794215732043e-07
# Max violation of equality constraints : 2.01391250570504e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_8 = 25.0
# rho_8 = 1
# tau_8 = 3.90625e-05
# 9-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_9 - x_8| = 1.0344019615769442e-06
# Max violation of equality constraints : 5.633377214708801e-07
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_9 = 25.0
# rho_9 = 1
# tau_9 = 1.953125e-05
# 10-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_10 - x_9| = 2.087388475565783e-06
# Max violation of equality constraints : 2.3719879071459893e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_10 = 25.0
# rho_10 = 1
# tau_10 = 9.765625e-06
# 11-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_11 - x_10| = 6.449995537577166e-07
# Max violation of equality constraints : 1.464299568987304e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_11 = 25.0
# rho_11 = 1
# tau_11 = 4.8828125e-06
# 12-th outer loop : Inner loop converges at 8 iteration(s) ...
# |x_12 - x_11| = 1.1224544036082697e-06
# Max violation of equality constraints : 1.1278129946612481e-07
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_12 = 25.0
# rho_12 = 1
# tau_12 = 2.44140625e-06
# 13-th outer loop : Inner loop converges at 19 iteration(s) ...
# |x_13 - x_12| = 8.207593164291086e-07
# Max violation of equality constraints : 1.2665788726717864e-06
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_13 = 25.0
# rho_13 = 1
# tau_13 = 1.220703125e-06
# 14-th outer loop : Inner loop converges at 22 iteration(s) ...
# |x_14 - x_13| = 8.844794130202384e-07
# Max violation of equality constraints : 2.2765712870409516e-08
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_14 = 25.0
# rho_14 = 1
# tau_14 = 1e-06
# 15-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_15 - x_14| = 2.2072433109287853e-08
# Max violation of equality constraints : 7.776198518438804e-09
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_15 = 25.0
# rho_15 = 1
# tau_15 = 1e-06
# 16-th outer loop : Inner loop converges at 0 iteration(s) ...
# |x_16 - x_15| = 0.0
# Max violation of equality constraints : 7.776198518438804e-09
# Max violation of inequality constraints : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# Outer loop converges at 16 iteration(s) !
# iter = 16 x* = [0.61879562 0.38120438], f(x*) = 0.14560702067782436, ∇L_A(x*) = [ 2.89045766e-07 -3.43300424e-07], max(ce(x*)) = 7.776198518438804e-09, max(ci(x*)) = 0.0
# ([array([-0.5, -0.5]),
#   array([0.71776152, 0.51402346]),
#   array([0.62754408, 0.39215768]),
#   array([0.6189767 , 0.38143059]),
#   array([0.61880184, 0.38121175]),
#   array([0.6187941 , 0.38120248]),
#   array([0.6187941 , 0.38120248]),
#   array([0.61879704, 0.38120615]),
#   array([0.61879651, 0.38120551]),
#   array([0.61879587, 0.38120469]),
#   array([0.61879456, 0.38120306]),
#   array([0.61879497, 0.38120356]),
#   array([0.61879567, 0.38120444]),
#   array([0.61879618, 0.38120508]),
#   array([0.61879563, 0.38120439]),
#   array([0.61879562, 0.38120438]),
#   array([0.61879562, 0.38120438])],
#  [np.float64(58.5),
#   np.float64(0.07979268949984009),
#   np.float64(0.1389969498975276),
#   np.float64(0.1454682871931394),
#   np.float64(0.14560238703791956),
#   np.float64(0.1456081847133062),
#   np.float64(0.1456081847133062),
#   np.float64(0.1456059332501736),
#   np.float64(0.1456063318341335),
#   np.float64(0.14560682608372705),
#   np.float64(0.14560782623116023),
#   np.float64(0.14560751695591068),
#   np.float64(0.14560697960057895),
#   np.float64(0.1456065864704959),
#   np.float64(0.14560701027135703),
#   np.float64(0.14560702067782436),
#   np.float64(0.14560702067782436)],
#  [array([-153., -150.]),
#   array([-0.00018661,  0.00015833]),
#   array([ 0.00053786, -0.00048457]),
#   array([-0.00028034,  0.00016416]),
#   array([1.88464825e-04, 2.09715884e-05]),
#   array([ 3.93415394e-06, -1.47732269e-06]),
#   array([-8.16681282e-05, -8.70796049e-05]),
#   array([-3.07274904e-06, -3.16833931e-07]),
#   array([4.17143391e-05, 5.33752384e-05]),
#   array([6.38554214e-05, 5.95814859e-05]),
#   array([ 1.52877160e-06, -1.12757775e-07]),
#   array([-3.22941595e-05, -3.80847026e-05]),
#   array([-3.12476434e-05, -3.23196954e-05]),
#   array([6.45268511e-07, 2.72926354e-07]),
#   array([-1.77369529e-07,  7.62651481e-07]),
#   array([ 4.83450729e-07, -1.48895461e-07]),
#   array([ 2.89045766e-07, -3.43300424e-07])],
#  [[np.float64(2.0)],
#   array([-0.23178497]),
#   array([-0.01970176]),
#   array([-0.00040729]),
#   array([-1.35916658e-05]),
#   array([3.42409129e-06]),
#   array([3.42409129e-06]),
#   array([-3.18371998e-06]),
#   array([-2.01391251e-06]),
#   array([-5.63337721e-07]),
#   array([2.37198791e-06]),
#   array([1.46429957e-06]),
#   array([-1.12781299e-07]),
#   array([-1.26657887e-06]),
#   array([-2.27657129e-08]),
#   array([7.77619852e-09]),
#   array([7.77619852e-09])],
#  [[np.float64(0.0)],
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.])],
#  [array([0.]),
#   array([0.23178497]),
#   array([0.33029375]),
#   array([0.34047603]),
#   array([0.34081582]),
#   array([0.34073022]),
#   array([0.34064461]),
#   array([0.34072421]),
#   array([0.34077455]),
#   array([0.34078864]),
#   array([0.34072934]),
#   array([0.34069273]),
#   array([0.34069555]),
#   array([0.34072721]),
#   array([0.34072778]),
#   array([0.34072759]),
#   array([0.34072739])],
#  [array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.]),
#   array([0.])])

# %%
result1_sqp = sqp(f=f1, f_torch=f1_torch, ce=ce_1, ce_torch=ce_1_torch, ci=ci_1, ci_torch=ci_1_torch, x0=x0_1, inner_opt=3, tol=1e-6, tol_inter=1e-4) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
# Out:
# max_lp = 1936391250174.43
# mu = 1936391250174.43
# Dphi1_0 = -431860012030210.5
# phi1_0 = 3872782500407.36
# phi1_k = 428002754687691.4
# phi1_k = 212058159743764.8
# phi1_k = 104092274910267.4
# phi1_k = 50109721924581.83
# phi1_k = 23118468381599.098
# phi1_k = 9622842878344.74
# phi1_k = 2875030187108.327
#
#  log - SQP
# ‖∆x‖ = 2.46e+00, x01 = [1.25961927, 1.22511693] | f = 1.3137e+01, ‖∇L‖ = 2.74e+12, ‖ce‖∞ = 1.48e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 1.94e+12, ‖ν‖ = 0.00e+00
#
# max_lp = 1575892899194.5645
# mu = 1575892899194.5645
# /home/cykwonlab/NumericalOptimizationCourse25/Assignment_3/../module_opt_AD.py:1344: SyntaxWarning: invalid escape sequence '\:'
#   f (callable) : objective function(output \: single scalar)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 result1_sqp = sqp(f=f1, f_torch=f1_torch, ce=ce_1, ce_torch=ce_1_torch, ci=ci_1, ci_torch=ci_1_torch, x0=x0_1, inner_opt=3, tol=1e-6, tol_inter=1e-4) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
#
# File ~/NumericalOptimizationCourse25/Assignment_3/../module_opt_AD.py:1499, in sqp(f, f_torch, ce, ce_torch, ci, ci_torch, x0, inner_opt, tol, tol_inter)
#    1497 if k == 0:
#    1498     mu = 1
# -> 1499 alpha, mu = steplength_merit2(k, mu, f, f_torch, ce, ce_torch, ci, ci_torch, x_k, p_new, grad_f_k, B_k, lmbda_k=lmbda_new, nu_k=nu_new) # step length alpha_k
#    1500 x_new = x_k + alpha*p_new # new point x_k+1
#    1501 f_new = f(x_new) # new f value f_k+1
#
# File ~/NumericalOptimizationCourse25/Assignment_3/../module_opt_AD.py:470, in steplength_merit2(k, mu, f, f_torch, ce, ce_torch, ci, ci_torch, x_k, p_k, grad_f_k, B_k, lmbda_k, nu_k)
#     467 phi1 = lambda alpha : f(x_k + alpha*p_k) + mu*(sum([abs(ce_j(x_k + alpha*p_k)) for ce_j in ce]) + sum([np.maximum(-ci_j(x_k + alpha*p_k), 0) for ci_j in ci])) # l1 merit function
#     469 # αk=0에서의 기울기 dφ1/dα(αk=0) 값 계산
# --> 470 sum_grad_ce = np.array([grad_ad(-ce_torch_j, x_k) if ce_j(x_k) < 0.0 else grad_ad(ce_torch_j, x_k) for ce_j, ce_torch_j in zip(ce, ce_torch)]).sum(axis=0)
#     471 sum_grad_ci = np.array([grad_ad(-ci_torch_j, x_k) if ci_j(x_k) < 0.0 else np.zeros_like(x_k) for ci_j, ci_torch_j in zip(ci, ci_torch)]).sum(axis=0)
#     472 Dphi1_0 = (grad_f_k + mu*(sum_grad_ce + sum_grad_ci)) @ p_k # 내가 직접 구한 dφ1/dα(αk=0)
#
# TypeError: bad operand type for unary -: 'function'

# %% [markdown]
# #### - Plot Convergence log of QPM, SQP for rosenbrock function with line equality constraint

# %%
grad_f_qpm_eqline = result1_qpm[2]
grad_f_sqp_eqline = result1_sqp[2]

# grad_f_sqp_eqline, grad_f_qpm_eqline : shape (n, 2)
# 각 iteration마다 gradient의 norm 계산
norm_qpm = np.linalg.norm(grad_f_qpm_eqline, axis=1)
norm_sqp = np.linalg.norm(grad_f_sqp_eqline, axis=1)

# x축 (iteration index)
iterations_qpm = np.arange(1, len(norm_qpm) + 1)
iterations_sqp = np.arange(1, len(norm_sqp) + 1)

# 그래프 그리기
plt.figure(figsize=(7,5))
plt.plot(iterations_qpm, norm_qpm, 'b-', label='QPM')
plt.plot(iterations_sqp, norm_sqp, 'r-', label='SQP')
plt.yscale('log')  # y축 로그 스케일

# 레이블, 제목, 범례
plt.xlabel('Iteration')
plt.ylabel('log |grad_f|')
plt.title('SQP vs QPM w.r.t. line equality constraint')
plt.legend()
plt.grid(True, which="both", ls="--", lw=0.5)
plt.tight_layout()
plt.show()

# %%
### define functions
f_rosenbrock_eqline = lambda x : (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
c_rosenbrock_eqline = lambda x : 1 - x[0] - x[1]

f_rosenbrock_eqdisk = lambda x : (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
c_rosenbrock_eqdisk = lambda x : 1 - x[0]**2 - x[1]**2

### grid and f value
step_rosenbrock_eq = .01
grid_rosenbrock_eq = np.meshgrid(np.arange(-1.5, 1.5+step_rosenbrock_eq, step_rosenbrock_eq), np.arange(-1.5, 1.5+step_rosenbrock_eq, step_rosenbrock_eq))
fval_grid_rosenbrock_eq = f_rosenbrock_eqline(grid_rosenbrock_eq)

### log of x of each method
x_sqp_eqline = result1_sqp[0]
x_qpm_eqline = result1_qpm[0]

# === Rosenbrock function (line equality constraint) ===
f_rosenbrock_eqline = lambda x, y: (1 - x)**2 + 100*(y - x**2)**2

# === Grid in the desired range ===
step_rosenbrock_eq = 0.01
xg, yg = np.meshgrid(
    np.arange(-1, 2 + step_rosenbrock_eq, step_rosenbrock_eq),
    np.arange(-1.5, 1.5 + step_rosenbrock_eq, step_rosenbrock_eq)
)
fval_grid_rosenbrock_eq = f_rosenbrock_eqline(xg, yg)

# === Extract paths ===
x_sqp_eqline = np.array(x_sqp_eqline)  # (n, 2)
x_qpm_eqline = np.array(x_qpm_eqline)  # (n, 2)

# === Plot contour and paths ===
plt.figure(figsize=(7,6))
contours = plt.contour(
    xg, yg, fval_grid_rosenbrock_eq,
    levels=np.logspace(-1, 3, 20), cmap='gray'
)
plt.clabel(contours, inline=True, fontsize=8, fmt="%.1f")

# SQP path (red)
plt.plot(x_sqp_eqline[:,0], x_sqp_eqline[:,1], 'r-o', label='SQP', markersize=3)
# QPM path (blue)
plt.plot(x_qpm_eqline[:,0], x_qpm_eqline[:,1], 'b-o', label='QPM', markersize=3)

# Constraint line c1(x,y)=1-x-y=0
xx = np.linspace(-1, 2, 300)
plt.plot(xx, 1 - xx, 'k--', lw=1, label='Constraint (1 - x - y = 0)')

# === Scope ===
plt.xlim([-1, 2])
plt.ylim([-1.5, 1.5])

# === Labels and formatting ===
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Path of Iterates on Rosenbrock Function (Line Equality Constraint)')
plt.legend()
plt.grid(True, ls='--', lw=0.5)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### - Solve Rosenbrock with Disk Constraint using SQP, QPM

# %%
f2 = f_rosenbrock_eqdisk # objective function
ce_2 = [c_rosenbrock_eqdisk] # equality constraints
ci_2 = [] # inequality constraints
x0_2 = np.array([0, 0])

# %%
x0_2 = np.array([-.5, .5])
result2_qpm = qpm(f=f2, ce=ce_2, ci=ci_2, x0=x0_2, inner_opt=3, tol=1e-4) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
# Out:
# mu_0 = 1
# tau_0 = 0.2
# Since ||grad(x0)|| = 68.60393574609752 > 0.2, x0 : [-0.5  0.5] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [-0.68402473  0.30822686]
# f_1 : 5.480696891722453
# ‖∇f(x_1)‖ : 56.52503560465513
# ‖∆x_1‖ : 0.26578570334077684
# recent alpha : 0.003874204890000001
# recent p : [-47.5 -49.5]
#
# BFGS
# x_2 : [-0.41022287  0.00518546]
# f_2 : 4.994657003726526
# ‖∇f(x_2)‖ : 43.587115171136176
# ‖∆x_2‖ : 0.4084134537715138
# recent alpha : 0.06561
# recent p : [ 4.1731728  -4.61882936]
#
# BFGS
# x_3 : [-0.51550293  0.30199134]
# f_3 : 2.6349031968345877
# ‖∇f(x_3)‖ : 8.55286581961951
# ‖∆x_3‖ : 0.3149247892260444
# recent alpha : 1
# recent p : [-0.10528006  0.29680588]
#
# BFGS
# x_4 : [-0.48553961  0.23823203]
# f_4 : 2.4577204693342107
# ‖∇f(x_4)‖ : 1.8087962213993607
# ‖∆x_4‖ : 0.07044892333576784
# recent alpha : 1
# recent p : [ 0.02996332 -0.06375932]
#
# BFGS
# x_5 : [-0.44118667  0.1829388 ]
# f_5 : 2.3886294296074166
# ‖∇f(x_5)‖ : 5.009359043305519
# ‖∆x_5‖ : 0.07088387931179842
# recent alpha : 1
# recent p : [ 0.04435294 -0.05529323]
#
# BFGS
# x_6 : [-0.33737225  0.07510438]
# f_6 : 2.326129440352249
# ‖∇f(x_6)‖ : 10.741898729344822
# ‖∆x_6‖ : 0.14968532436758256
# recent alpha : 1
# recent p : [ 0.10381442 -0.10783442]
#
# BFGS
# x_7 : [-0.34083114  0.09440468]
# f_7 : 2.227927247330305
# ‖∇f(x_7)‖ : 6.777172495139225
# ‖∆x_7‖ : 0.01960779068558591
# recent alpha : 1
# recent p : [-0.00345889  0.0193003 ]
#
# BFGS
# x_8 : [-0.24474055  0.05068767]
# f_8 : 1.9973458271049735
# ‖∇f(x_8)‖ : 3.514298621133987
# ‖∆x_8‖ : 0.10556789193053509
# recent alpha : 1
# recent p : [ 0.0960906  -0.04371701]
#
# BFGS
# x_9 : [-0.17847943  0.01391824]
# f_9 : 1.8894511182418101
# ‖∇f(x_9)‖ : 4.888770731484601
# ‖∆x_9‖ : 0.07577945731372702
# recent alpha : 0.23129339280452935
# recent p : [ 0.28648079 -0.15897311]
#
# BFGS
# x_10 : [-0.11017253 -0.01402007]
# f_10 : 1.7886489350727115
# ‖∇f(x_10)‖ : 6.085867554280642
# ‖∆x_10‖ : 0.07379961095753196
# recent alpha : 0.2614503273873762
# recent p : [ 0.26126151 -0.10685895]
#
# BFGS
# x_11 : [ 0.0401067  -0.04524741]
# f_11 : 1.6372940763590886
# ‖∇f(x_11)‖ : 9.364561943974973
# ‖∆x_11‖ : 0.15348938589500055
# recent alpha : 1
# recent p : [ 0.15027922 -0.03122735]
#
# BFGS
# x_12 : [ 0.06394353 -0.00901108]
# f_12 : 1.3892010483834858
# ‖∇f(x_12)‖ : 3.0888141086440326
# ‖∆x_12‖ : 0.043373572119211466
# recent alpha : 1
# recent p : [0.02383683 0.03623634]
#
# BFGS
# x_13 : [0.22808415 0.02127925]
# f_13 : 1.1392696912397793
# ‖∇f(x_13)‖ : 6.244191337605093
# ‖∆x_13‖ : 0.16691209829552417
# recent alpha : 1
# recent p : [0.16414062 0.03029033]
#
# BFGS
# x_14 : [0.33074526 0.07829607]
# f_14 : 0.9357502880962405
# ‖∇f(x_14)‖ : 6.724519713857101
# ‖∆x_14‖ : 0.11743177441670642
# recent alpha : 1
# recent p : [0.10266111 0.05701682]
#
# BFGS
# x_15 : [0.45038869 0.22805806]
# f_15 : 0.6432338269517195
# ‖∇f(x_15)‖ : 7.870532173661572
# ‖∆x_15‖ : 0.19168516686445436
# recent alpha : 1
# recent p : [0.11964343 0.14976199]
#
# BFGS
# x_16 : [0.56151587 0.31436567]
# f_16 : 0.36397990227803734
# ‖∇f(x_16)‖ : 1.4366792581855317
# ‖∆x_16‖ : 0.14070626616634122
# recent alpha : 0.19
# recent p : [0.5848799  0.45425057]
#
# BFGS
# x_17 : [0.61485791 0.36125309]
# f_17 : 0.297308458734205
# ‖∇f(x_17)‖ : 4.625578673087991
# ‖∆x_17‖ : 0.07101974094360544
# recent alpha : 0.1
# recent p : [0.53342041 0.46887421]
#
# BFGS
# x_18 : [0.6610202  0.41230604]
# f_18 : 0.2528750106682331
# ‖∇f(x_18)‖ : 7.474483545573186
# ‖∆x_18‖ : 0.06882848451431643
# recent alpha : 1
# recent p : [0.04616229 0.05105295]
#
# BFGS
# x_19 : [0.71514836 0.48771296]
# f_19 : 0.16884925996481864
# ‖∇f(x_19)‖ : 7.695004087542469
# ‖∆x_19‖ : 0.0928227419599203
# recent alpha : 1
# recent p : [0.05412816 0.07540692]
#
# BFGS
# x_20 : [0.77354668 0.59254793]
# f_20 : 0.055951709131774705
# ‖∇f(x_20)‖ : 1.765919584356766
# ‖∆x_20‖ : 0.12000306573777947
# recent alpha : 1
# recent p : [0.05839832 0.10483497]
#
# BFGS
# x_21 : [0.80907328 0.65022593]
# f_21 : 0.04136074643634595
# ‖∇f(x_21)‖ : 1.393577444359291
# ‖∆x_21‖ : 0.06774134719423029
# recent alpha : 1
# recent p : [0.0355266 0.057678 ]
#
# BFGS
# x_22 : [0.81026588 0.6582362 ]
# f_22 : 0.0403224041337132
# ‖∇f(x_22)‖ : 0.9109357871818868
# ‖∆x_22‖ : 0.008098562285390786
# recent alpha : 1
# recent p : [0.00119261 0.00801027]
#
# ‖∇f(x_23)‖ : 0.012679975056371046 / tol_∇f : 0.2 / ‖∆x_23‖ : 0.00484823663005353 / tol_∆x : 0.002
# BFGS
#  Optimization converges -> Iteration : 23 / x* : [0.81378739 0.66156852] / f(x*) : 0.03971385142986664 / ‖∇f(x*)‖ : 0.012679975056371046 ‖∆x*‖ : 0.00484823663005353
#
# 1-th outer loop : Inner loop converges at 23 iteration(s) ...
# |x_1 - x_0| = 1.3236848918494635
# # of violated ce constraints : 1, violation : -0.09992282637605049
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_1 = 5
# tau_1 = 0.1
# Since ||grad(x0)|| = 0.8451920106536823 > 0.1, x0 : [0.81378739 0.66156852] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.80273813 0.65281668]
# f_1 : 0.05846178042741034
# ‖∇f(x_1)‖ : 3.321060027529534
# ‖∆x_1‖ : 0.01409542073277804
# recent alpha : 0.016677181699666574
# recent p : [-0.66253757 -0.52477948]
#
# BFGS
# x_2 : [0.77599385 0.60001054]
# f_2 : 0.05421960012562053
# ‖∇f(x_2)‖ : 0.6620717015507408
# ‖∆x_2‖ : 0.05919243733930161
# recent alpha : 0.013504776923556314
# recent p : [-1.9803572  -3.91018203]
#
# BFGS
# x_3 : [0.79229603 0.62740474]
# f_3 : 0.04429337489110825
# ‖∇f(x_3)‖ : 0.15768108639439438
# ‖∆x_3‖ : 0.03187793965068377
# recent alpha : 1
# recent p : [0.01630218 0.02739419]
#
# ‖∇f(x_4)‖ : 0.009642766223334764 / tol_∇f : 0.1 / ‖∆x_4‖ : 0.0009397502347258907 / tol_∆x : 0.001
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.792954   0.62807571] / f(x*) : 0.044269097434576146 / ‖∇f(x*)‖ : 0.009642766223334764 ‖∆x*‖ : 0.0009397502347258907
#
# 2-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_2 - x_1| = 0.03944361100255292
# # of violated ce constraints : 1, violation : -0.023255149501448857
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_2 = 25
# tau_2 = 0.05
# Since ||grad(x0)|| = 0.9388051744941388 > 0.05, x0 : [0.792954   0.62807571] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.78512911 0.62174948]
# f_1 : 0.04911412546953246
# ‖∇f(x_1)‖ : 2.2964022919005167
# ‖∆x_1‖ : 0.010062318363232315
# recent alpha : 0.010718217833273272
# recent p : [-0.73005569 -0.59023203]
#
# BFGS
# x_2 : [0.78329893 0.61292553]
# f_2 : 0.048447843906464276
# ‖∇f(x_2)‖ : 0.7999609988307581
# ‖∆x_2‖ : 0.009011746894251396
# recent alpha : 0.004967674302142575
# recent p : [-0.36841731 -1.77627317]
#
# ‖∇f(x_3)‖ : 0.017896507746216348 / tol_∇f : 0.05 / ‖∆x_3‖ : 0.00817787333522765 / tol_∆x : 0.0005
# BFGS
#  Optimization converges -> Iteration : 3 / x* : [0.78772485 0.61980222] / f(x*) : 0.04538295163182342 / ‖∇f(x*)‖ : 0.017896507746216348 ‖∆x*‖ : 0.00817787333522765
#
# 3-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_3 - x_2| = 0.009787478582162626
# # of violated ce constraints : 1, violation : -0.004665224551079594
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_3 = 125
# tau_3 = 0.025
# Since ||grad(x0)|| = 0.923253008375077 > 0.025, x0 : [0.78772485 0.61980222] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.78541373 0.61792957]
# f_1 : 0.04626227388809578
# ‖∇f(x_1)‖ : 1.0136053991639056
# ‖∆x_1‖ : 0.002974573949787816
# recent alpha : 0.003221840516959754
# recent p : [-0.71732822 -0.5812369 ]
#
# BFGS
# x_2 : [0.78582554 0.61669169]
# f_2 : 0.046233799188601384
# ‖∇f(x_2)‖ : 0.7764897788230799
# ‖∆x_2‖ : 0.0013045850817795244
# recent alpha : 0.00347963356740231
# recent p : [ 0.11834905 -0.35575089]
#
# ‖∇f(x_3)‖ : 0.004640478300517572 / tol_∇f : 0.025 / ‖∆x_3‖ : 0.0016876721318090807 / tol_∆x : 0.00025
# BFGS
#  Optimization converges -> Iteration : 3 / x* : [0.78669649 0.61813726] / f(x*) : 0.04561589909555102 / ‖∇f(x*)‖ : 0.004640478300517572 ‖∆x*‖ : 0.0016876721318090807
#
# 4-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_4 - x_3| = 0.0019569396994552945
# # of violated ce constraints : 1, violation : -0.0009850355474177452
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_4 = 625
# tau_4 = 0.0125
# Since ||grad(x0)|| = 0.9898662109275369 > 0.0125, x0 : [0.78669649 0.61813726] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.78613699 0.61769914]
# f_1 : 0.04580664924696414
# ‖∇f(x_1)‖ : 0.8571275351586789
# ‖∆x_1‖ : 0.0007106229609090231
# recent alpha : 0.0007178979876918527
# recent p : [-0.77934784 -0.6102885 ]
#
# BFGS
# x_2 : [0.78628422 0.61747683]
# f_2 : 0.04580496620136002
# ‖∇f(x_2)‖ : 0.8405454788696464
# ‖∆x_2‖ : 0.0002666331341338453
# recent alpha : 0.003215007647393601
# recent p : [ 0.04579179 -0.06914582]
#
# BFGS
# x_3 : [0.78648041 0.61779348]
# f_3 : 0.04566322018013164
# ‖∇f(x_3)‖ : 0.03347103428185507
# ‖∆x_3‖ : 0.00037250559284288034
# recent alpha : 1
# recent p : [0.0001962  0.00031665]
#
# ‖∇f(x_4)‖ : 1.954377004273733e-05 / tol_∇f : 0.0125 / ‖∆x_4‖ : 1.2961336379679453e-05 / tol_∆x : 0.000125
# BFGS
#  Optimization converges -> Iteration : 4 / x* : [0.78647034 0.61778532] / f(x*) : 0.045663004388365326 / ‖∇f(x*)‖ : 1.954377004273733e-05 ‖∆x*‖ : 1.2961336379679453e-05
#
# 5-th outer loop : Inner loop converges at 4 iteration(s) ...
# |x_5 - x_4| = 0.00041833213650092357
# # of violated ce constraints : 1, violation : -0.00019430159348715614
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# mu_5 = 3125
# tau_5 = 0.00625
# Since ||grad(x0)|| = 0.9715833521059531 > 0.00625, x0 : [0.78647034 0.61778532] is not an optimum point. Optimization begins !
# BFGS
# x_1 : [0.78635843 0.61769742]
# f_1 : 0.04569930798000614
# ‖∇f(x_1)‖ : 0.8190228809298185
# ‖∆x_1‖ : 0.0001423011945608013
# recent alpha : 0.000146463187386248
# recent p : [-0.76404443 -0.60017524]
#
# BFGS
# x_2 : [0.78639512 0.61764939]
# f_2 : 0.0456992186346747
# ‖∇f(x_2)‖ : 0.8155033954571712
# ‖∆x_2‖ : 6.043991105815823e-05
# recent alpha : 0.0035752347829119606
# recent p : [ 0.01026174 -0.01343432]
#
# ‖∇f(x_3)‖ : 0.151841828360701 / tol_∇f : 0.00625 / ‖∆x_3‖ : 8.459948668774583e-05 / tol_∆x : 6.25e-05
# BFGS
#  Optimization converges -> Iteration : 3 / x* : [0.78643511 0.61772394] / f(x*) : 0.045673363639059605 / ‖∇f(x*)‖ : 0.151841828360701 ‖∆x*‖ : 8.459948668774583e-05
#
# 6-th outer loop : Inner loop converges at 3 iteration(s) ...
# |x_6 - x_5| = 7.077301640609653e-05
# # of violated ce constraints : 0, violation : 0.0
# # of violated ci constraints : 0, violation : 0.0
#
# ------------------------------------------------------------- Outer loop ----------------------------------------------------------------
#
# Outer loop converged at 6 iteration(s) !
# iter = 6 x* = [0.78643511 0.61772394], f(x*) = 0.045667152301081454, |ce(x*)|₁ = 6.304963367076422e-05, |ci(x*)|₁ = 0.0

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 위와 같이 지금 현재 문제에는 총 5개의 KKT stationary points(∇L = 0)가 존재함.
# SQP는 initial point에서 가장 가까운 KKT point로 수렴할 뿐임.

# %%
x0_2 = np.array([1.5, 1.5])
result2_sqp = sqp(f=f2, ce=ce_2, ci=ci_2, x0=x0_2, inner_opt=3, tol=1e-6, tol_inter=1e-4) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
# result2_sqp = alm(f=f2, ce=ce_2, ci=ci_2, x0=x0_2, inner_opt=3, tol=1e-6) # inner_opt -> 0:stp_descent 1:cg_hs 2:cg_fr 3:quasi_newton_bfgs
# Out:
#  log - SQP
# ‖∆x‖ = 4.15e-01, x01 = [1.20597331, 1.79288737] | f = 1.1502e+01, ‖∇L‖ = 3.05e+02, ‖ce‖∞ = 3.67e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 5.00e+01, ‖ν‖ = 0.00e+00
#
#
#  log - SQP
# ‖∆x‖ = 9.21e-01, x02 = [1.02853201, 0.88908329] | f = 2.8500e+00, ‖∇L‖ = 7.42e+01, ‖ce‖∞ = 8.48e-01, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 3.32e+00, ‖ν‖ = 0.00e+00
#
#
#  log - SQP
# ‖∆x‖ = 3.28e-01, x03 = [0.85788178, 0.60940832] | f = 1.6218e+00, ‖∇L‖ = 5.24e+01, ‖ce‖∞ = 1.07e-01, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 2.55e+00, ‖ν‖ = 0.00e+00
#
#
#  log - SQP
# ‖∆x‖ = 8.41e-02, x04 = [0.79068344, 0.65997104] | f = 1.6485e-01, ‖∇L‖ = 1.55e+01, ‖ce‖∞ = 6.07e-02, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 6.45e+00, ‖ν‖ = 0.00e+00
#
#
#  log - SQP
# ‖∆x‖ = 4.12e-02, x05 = [0.78650522, 0.61895799] | f = 4.5594e-02, ‖∇L‖ = 5.21e-01, ‖ce‖∞ = 1.70e-03, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 1.99e-02, ‖ν‖ = 0.00e+00
#
#
#  log - SQP
# ‖∆x‖ = 1.26e-03, x06 = [0.78641428, 0.61770144] | f = 4.5675e-02, ‖∇L‖ = 2.82e-03, ‖ce‖∞ = 2.50e-06, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 1.21e-01, ‖ν‖ = 0.00e+00
#
#
# Final iterate: x* = [0.78641428 0.61770144]
# f(x*)         = 0.04567450736606423
# λ*            = [0.12147433]
# ν*            = [0.]
# ‖∇L(x*)‖     = 1.696e-03
# ‖ce(x*)‖∞   = 2.497e-06
# ‖ci(x*)‖∞ = 0.000e+00

# %% [markdown]
# #### - Plot Convergence log of QPM, SQP for rosenbrock function with disk equality constraint

# %%
grad_f_qpm_eqdisk = result2_qpm[2]
grad_f_sqp_eqdisk = result2_sqp[2]

# grad_f_sqp_eqdisk, grad_f_qpm_eqdisk : shape (n, 2)
# 각 iteration마다 gradient의 norm 계산
norm_qpm = np.linalg.norm(grad_f_qpm_eqdisk, axis=1)
norm_sqp = np.linalg.norm(grad_f_sqp_eqdisk, axis=1)

# x축 (iteration index)
iterations_qpm = np.arange(1, len(norm_qpm) + 1)
iterations_sqp = np.arange(1, len(norm_sqp) + 1)

# 그래프 그리기
plt.figure(figsize=(7,5))
plt.plot(iterations_qpm, norm_qpm, 'b-', label='QPM')
plt.plot(iterations_sqp, norm_sqp, 'r-', label='SQP')
plt.yscale('log')  # y축 로그 스케일

# 레이블, 제목, 범례
plt.xlabel('Iteration')
plt.ylabel('log |grad_f|')
plt.title('SQP vs QPM w.r.t. disk equality constraint')
plt.legend()
plt.grid(True, which="both", ls="--", lw=0.5)
plt.tight_layout()
plt.show()

# %%
### define functions
f_rosenbrock_eqline = lambda x : (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
c_rosenbrock_eqline = lambda x : 1 - x[0] - x[1]

f_rosenbrock_eqdisk = lambda x : (1 - x[0])**2 + 100*(x[1] - x[0]**2)**2
c_rosenbrock_eqdisk = lambda x : 1 - x[0]**2 - x[1]**2

### grid and f value
step_rosenbrock_eq = .01
grid_rosenbrock_eq = np.meshgrid(np.arange(-1.5, 1.5+step_rosenbrock_eq, step_rosenbrock_eq), np.arange(-1.5, 1.5+step_rosenbrock_eq, step_rosenbrock_eq))
fval_grid_rosenbrock_eq = f_rosenbrock_eqline(grid_rosenbrock_eq)

### log of x of each method
x_sqp_eqdisk = result2_sqp[0]
x_qpm_eqdisk = result2_qpm[0]

# === Rosenbrock function (disk equality constraint) ===
f_rosenbrock_eqdisk = lambda x, y: (1 - x)**2 + 100*(y - x**2)**2
c_rosenbrock_eqdisk = lambda x, y: 1 - x**2 - y**2

# === Grid in the desired range ===
step_rosenbrock_eq = 0.01
xg, yg = np.meshgrid(
    np.arange(-1, 2 + step_rosenbrock_eq, step_rosenbrock_eq),
    np.arange(-1.5, 1.5 + step_rosenbrock_eq, step_rosenbrock_eq)
)
fval_grid_rosenbrock_eq = f_rosenbrock_eqdisk(xg, yg)

# === Extract optimization paths ===
x_sqp_eqdisk = np.array(x_sqp_eqdisk)  # (n, 2)
x_qpm_eqdisk = np.array(x_qpm_eqdisk)  # (n, 2)

# === Plot contour and paths ===
plt.figure(figsize=(7,6))
contours = plt.contour(
    xg, yg, fval_grid_rosenbrock_eq,
    levels=np.logspace(-1, 3, 20), cmap='gray'
)
plt.clabel(contours, inline=True, fontsize=8, fmt="%.1f")

# SQP path (red)
plt.plot(x_sqp_eqdisk[:,0], x_sqp_eqdisk[:,1], 'r-o', label='SQP', markersize=3)
# QPM path (blue)
plt.plot(x_qpm_eqdisk[:,0], x_qpm_eqdisk[:,1], 'b-o', label='QPM', markersize=3)

# === Constraint circle: 1 - x^2 - y^2 = 0 ===
theta = np.linspace(0, 2*np.pi, 300)
plt.plot(np.cos(theta), np.sin(theta), 'k--', lw=1, label='Constraint (1 - x² - y² = 0)')

# === Scope ===
plt.xlim([-1, 2])
plt.ylim([-1.5, 1.5])

# === Labels and formatting ===
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Path of Iterates on Rosenbrock Function (Disk Equality Constraint)')
plt.legend()
plt.grid(True, ls='--', lw=0.5)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Assignment\#3(Constrained Optimization) - Problem 2
# maximize Breguet range
# s.t. closed V[v/s], h[m] range
#
# 1st Algorithm : QPM(Quadratic Penalty Method)
# 2nd Algorithm : ALM(Augmented Lagrangian Method)
# 3rd Algorithm : SQP(Sequential Quadratic Programming)

# %% [markdown]
# ### Breguet range function

# %%
def range_breguet(x, fuel_remain):
    
    V = x[0] # [m/s]
    h = x[1] # [m]
    # if any(isinstance(element, (list, np.ndarray)) for element in x): # x가 리스트나 ndarray를 원소로 가진 tuple이면 배열 전체에 상/하한 제한
    #     V[np.where(V < .1)] = .1
    #     V[np.where(V > 400)] = 400
    #     h[np.where(h < .1)] = .1
    #     h[np.where(h > 25000)] = 25000
    # else: # x가 그냥 ndarray이면 그냥 각 원소에 상/하한 제한
    #     if V < 1:
    #         V = 1
    #     elif V > 400:
    #         V = 400
        
    #     if h < 1:
    #         h = 1
    #     elif h > 25000:
    #         h = 25000

    # Parameter setting
    g = 9.81 # Gravity acceleration [m*s2]
    c = 343 # Sound speed [m/s]
    e = .8 # Oswald efficiency factor
    C_D0 = .0083 # Zero lift drage coefficient
    AR = 10 # Aspect ratio of the wing
    S = 100 # Platform area [m2]
    W_e = 162400 # Empty weight of the aircraft [kg]
    W_fuel = 146571 # Initial fuel weigh of the aricraft [kg]
    A_t = 1.3295 # Surface area of the turbine [m2]
    FAR = .1 # Fuel ratio over the air

    # Intermediate variables
    rho_air = 1.2*(1 - .0065*h/288)**5.26 # Air density [kg/m3]
    W_f = W_e + (W_fuel*fuel_remain) # Weight of the aircraft after flight [kg]
    L = W_f*g # Lift force [N]
    C_L = 2*L/(rho_air*(V**2)*S) # Lift Coefficient
    C_WD = 10*(np.arctan(10*((V/(.7*c))**2 - 1)) + .5*np.pi) # Wave drag coefficient
    # C_WD = 0.06*np.maximum(0.0, (V/c)-0.72)**2
    C_D = C_D0 + (C_L**2)/(np.pi*e*AR) + C_WD # Drag coefficient
    D = .5*C_D*rho_air*(V**2)*S # Drag force [N]
    T = D # Thrust force = Drag force [N]
    W_i = W_e + W_fuel # Initial weight of the aircraft [kg]
    m_air = V*A_t*rho_air # Mass rate of air [kg/s]
    m_f = m_air*FAR # Mass rate of fuel [kg/s]
    c_t = m_f/T + 1e-5 # Specific fuel consumption [kg/(s*N)]

    # Range
    result = (V/c_t)*(C_L/C_D)*np.log(W_i/W_f) # Maximum range of aircraft from Breguet Eqn [m]
    # Range = np.round(Range*.001)

    return result

# %%
func = lambda x : -1 * range_breguet(x, fuel_remain=.75) # max f 가 목표이기 때문에 -1 곱한 걸 목적함수로 정의
const_lb_V = lambda x : x[0] - 1
const_ub_V = lambda x : -x[0] + 150 # 1[m/s] ≤ V ≤ 150[m/s]
const_lb_h = lambda x : x[1] - 1
const_ub_h = lambda x : -x[1] + 2*(10**4) # 1[m] ≤ h ≤ 20000[m]

x_cur = np.array([400, 22000]) # V[m/s], h[m], Fuel_remain_AfterFlight(0, 1)

# 제약조건
const_e = [] # 등호제약조건
const_i = [const_lb_V, const_lb_h, const_ub_V, const_ub_h] # 부등호제약조건

# 최적화
result = sqp(f=func, ce=const_e, ci=const_i, x0=x_cur, inner_opt=3, tol=1e-6, tol_inter=1e-4)
# result = alm(func, const_e, const_i, x_cur, 3, 1e-4)
# result = qpm(func, const_e, const_i, x_cur, 3, 1e-4)
# Out:
#  log - SQP
# ‖∆x‖ = 2.04e+03, x01 = [0.99999989, 20000.00000021] | f = -3.0294e-01, ‖∇L‖ = 2.79e+03, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 2.11e-07, ‖λ‖ = 0.00e+00, ‖ν‖ = 2.79e+03
#
#
#  log - SQP
# ‖∆x‖ = 1.86e-01, x02 = [1.18647328, 19999.99999226] | f = -5.0598e-01, ‖∇L‖ = 1.28e+00, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 1.31e-02
#
#
#  log - SQP
# ‖∆x‖ = 1.31e+00, x03 = [2.49898689, 19999.99999794] | f = -4.7277e+00, ‖∇L‖ = 5.68e+00, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 3.96e-02
#
#
#  log - SQP
# ‖∆x‖ = 2.91e+01, x04 = [31.61179551, 19999.99999707] | f = -9.5677e+03, ‖∇L‖ = 9.08e+02, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 7.17e-01
# /home/chiyoung0/NumericalOptimization_25/Assignment_3/../module_opt.py:497: RuntimeWarning: divide by zero encountered in scalar divide
#   mu = max(max_lp, ((grad_f_k @ p_k) + .5*sigma*pBp)/((1 - rho)*sum_c)) # penalty parameter for constraint terms in phi1
#  log - SQP
# ‖∆x‖ = 1.18e+02, x05 = [150.00000065, 19999.99999925] | f = -9.8355e+05, ‖∇L‖ = 1.78e+04, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 6.49e-07, ‖λ‖ = 0.00e+00, ‖ν‖ = 9.03e+02
#
#
#  log - SQP
# ‖∆x‖ = 1.73e+03, x06 = [149.99999840, 18272.77798837] | f = -1.3567e+06, ‖∇L‖ = 5.75e+03, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 1.86e+04
#
#
#  log - SQP
# ‖∆x‖ = 1.02e+04, x07 = [149.99999982, 8046.94317722] | f = -2.2930e+06, ‖∇L‖ = 4.65e+04, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 4.71e+04
#
#
#  log - SQP
# ‖∆x‖ = 4.02e+03, x08 = [149.99999859, 12063.09946285] | f = -2.5503e+06, ‖∇L‖ = 1.09e+04, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 9.90e+03
#
#
#  log - SQP
# ‖∆x‖ = 1.05e+03, x09 = [149.99999663, 11010.60273587] | f = -2.5696e+06, ‖∇L‖ = 4.21e+02, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 1.55e+04
#
#
#
#
#  log - SQP
# ‖∆x‖ = 2.44e+02, x10 = [150.00000475, 11254.10699874] | f = -2.5717e+06, ‖∇L‖ = 3.78e+01, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 4.75e-06, ‖λ‖ = 0.00e+00, ‖ν‖ = 1.64e+04
#
#
#  log - SQP
# ‖∆x‖ = 6.81e+00, x11 = [149.99999613, 11260.91615487] | f = -2.5717e+06, ‖∇L‖ = 1.57e-01, ‖ce‖∞ = 0.00e+00, ‖ci‖∞ = 0.00e+00, ‖λ‖ = 0.00e+00, ‖ν‖ = 1.65e+04
#
# alpha_k did not meet the armijo condition ...
#
# Final iterate: x* = [  149.99999613 11260.91615487]
# f(x*)         = -2571653.3054641546
# λ*            = [0.]
# ν*            = [    0.             0.         16459.39413375     0.        ]
# ‖∇L(x*)‖     = 4.775e-01
# ‖ce(x*)‖∞   = 0.000e+00
# ‖ci(x*)‖∞ = 0.000e+00
# /home/chiyoung0/NumericalOptimization_25/Assignment_3/../module_opt.py:507: RuntimeWarning: invalid value encountered in scalar multiply
#   Dphi1_0 = -p_k @ grad_f_k - mu*sum_c # directional derivative wrt pk at x0
# /home/chiyoung0/NumericalOptimization_25/Assignment_3/../module_opt.py:510: RuntimeWarning: invalid value encountered in scalar multiply
#   Dphi1_0 = -pBp + (p_k @ A_lmbda) + (p_k @ A_nu) - mu*sum_c
# /home/chiyoung0/NumericalOptimization_25/Assignment_3/../module_opt.py:506: RuntimeWarning: invalid value encountered in scalar multiply
#   phi1 = lambda alpha : f(x_k + alpha*p_k) + mu*(sum([abs(ce_j(x_k + alpha*p_k)) for ce_j in ce]) + sum([np.maximum(-ci_j(x_k + alpha*p_k), 0) for ci_j in ci])) # l1 merit function
